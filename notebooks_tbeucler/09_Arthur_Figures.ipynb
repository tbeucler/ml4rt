# %% [markdown]
# <a href="https://colab.research.google.com/github/tbeucler/ml4rt/blob/master/notebooks_tbeucler/09_Arthur_Figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
# Upgrades (necessary to load the pkl file)
# !pip install seaborn --upgrade
# !pip install psy-maps --upgrade
#!pip install xarray --upgrade
# Out:
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (0.14.1)
# Collecting xarray
#   Using cached xarray-2024.3.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from xarray) (1.25.2)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.10/dist-packages (from xarray) (24.0)
# Collecting pandas>=1.5 (from xarray)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 89.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->xarray) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->xarray) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->xarray) (1.16.0)
# Installing collected packages: pandas, xarray
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: xarray
#     Found existing installation: xarray 0.14.1
#     Uninstalling xarray-0.14.1:
#       Successfully uninstalled xarray-0.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.2.2 which is incompatible.
# Successfully installed pandas-2.2.2 xarray-2024.3.0

# %%
# Arthur environment
# !pip install numpy==1.20.2
# !pip install xarray==0.14.1
# !pip install pandas==1.3.5
# Out:
# Collecting numpy==1.20.2
#   Using cached numpy-1.20.2.zip (7.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: numpy
#   error: subprocess-exited-with-error
#
#   × Building wheel for numpy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for numpy (pyproject.toml) ... error
#   ERROR: Failed building wheel for numpy
# Failed to build numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects
# Requirement already satisfied: xarray==0.14.1 in /usr/local/lib/python3.10/dist-packages (0.14.1)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.10/dist-packages (from xarray==0.14.1) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from xarray==0.14.1) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->xarray==0.14.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->xarray==0.14.1) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->xarray==0.14.1) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24->xarray==0.14.1) (1.16.0)
# Collecting pandas==1.3.5
#   Using cached pandas-1.3.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.5) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.5) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.5) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.5) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.15.1 requires xarray>=0.21.0, but you have xarray 0.14.1 which is incompatible.
# bigframes 1.2.0 requires pandas>=1.5.0, but you have pandas 1.3.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 1.3.5 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.3.5 which is incompatible.
# statsmodels 0.14.2 requires pandas!=2.1.0,>=1.4, but you have pandas 1.3.5 which is incompatible.
# xarray-einstats 0.7.0 requires xarray>=2022.09.0, but you have xarray 0.14.1 which is incompatible.
# Successfully installed pandas-1.3.5

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager
from matplotlib import colors
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib import ticker

import pandas as pd
import numpy as np
import pickle as pkl
import json

from scipy.stats import linregress
from scipy.optimize import curve_fit
from scipy.stats import linregress
from scipy.stats import binned_statistic

import psyplot.project as psy
import cartopy.crs as ccrs
import xarray as xr

# %%
print(xr.__version__)
print(pd.__version__)
print(np.__version__)
# Out:
# 2024.3.0
# 2.2.2

# %%
fz = 40
lw = 2
siz = 100

plt.rc('text', usetex=False)
matplotlib.rcParams['mathtext.fontset'] = 'custom'
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.family'] = 'STIXGeneral'
mpl.rcParams['lines.linewidth'] = lw
plt.rc('font',size=fz)

# %% [markdown]
# ## Open pkl data

# %%
base_path = "/content/"
paths = [
    "cold_output_cond_10_bins.pkl",
    "hot_output_cond_10_bins.pkl",
    "nn_preds_cold_cond_10_bins.pkl",
    "nn_preds_hot_cond_10_bins.pkl",
    "pysr_preds_cold_cond_10_bins.pkl",
    "pysr_preds_hot_cond_10_bins.pkl",
    "sundq_preds_cold_cond_10_bins.pkl",
    "sundq_preds_hot_cond_10_bins.pkl",
    "wgrid_20160811-15_timmean_sfs4nn-ref.pkl",
    "wgrid_20160811-15_timmean_sfs5nn-ref.pkl",
    "wgrid_sellev_scaled_20160811-0815_timmean.pkl"
]

paths = [base_path + path for path in paths]

# %%
# Initialize a dictionary to store the contents of the pickle files
contents = {}

# Load each pickle file and store its content in the dictionary
for path in paths:
    try:
        with open(path, 'rb') as file:
            contents[path] = pkl.load(file)
    except Exception as e:
        contents[path] = f"Error loading file: {e}"

contents.keys()  # Show the keys to confirm the operation without displaying the actual data
# Out:
# dict_keys(['/content/cold_output_cond_10_bins.pkl', '/content/hot_output_cond_10_bins.pkl', '/content/nn_preds_cold_cond_10_bins.pkl', '/content/nn_preds_hot_cond_10_bins.pkl', '/content/pysr_preds_cold_cond_10_bins.pkl', '/content/pysr_preds_hot_cond_10_bins.pkl', '/content/sundq_preds_cold_cond_10_bins.pkl', '/content/sundq_preds_hot_cond_10_bins.pkl', '/content/wgrid_20160811-15_timmean_sfs4nn-ref.pkl', '/content/wgrid_20160811-15_timmean_sfs5nn-ref.pkl', '/content/wgrid_sellev_scaled_20160811-0815_timmean.pkl'])

# %% [markdown]
# ## Arthur's quickplot tests

# %% [markdown]
# ### Feature assimilation

# %%
pkl_file = contents['/content/wgrid_sellev_scaled_20160811-0815_timmean.pkl']

# %%
pkl_file
# Out:
# "Error loading file: No module named 'pandas.core.indexes.numeric'"

# %%
coordlist = ["clat_bnds", "clon_bnds"]
coord_in = [coord for coord in pkl_file.data_vars if coord in coordlist]

# %%
pkl_file = pkl_file.set_coords("clat_bnds")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-00e582626b64> in <cell line: 1>()
# ----> 1 pkl_file = pkl_file.set_coords("clat_bnds")
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in set_coords(self, names)
#    2030             names = list(names)
#    2031         self._assert_all_in_dataset(names)
# -> 2032         obj = self.copy()
#    2033         obj._coord_names.update(names)
#    2034         return obj
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in copy(self, deep, data)
#    1333         pandas.DataFrame.copy
#    1334         """
# -> 1335         return self._copy(deep=deep, data=data)
#    1336
#    1337     def _copy(
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in _copy(self, deep, data, memo)
#    1362                 )
#    1363
# -> 1364         indexes, index_vars = self.xindexes.copy_indexes(deep=deep)
#    1365
#    1366         variables = {}
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/indexes.py in copy_indexes(self, deep, memo)
#    1639                 convert_new_idx = False
#    1640
# -> 1641             new_idx = idx._copy(deep=deep, memo=memo)
#    1642             idx_vars = idx.create_variables(coords)
#    1643
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/indexes.py in _copy(self, deep, memo)
#     850             # index will be copied in constructor
#     851             index = self.index
# --> 852         return self._replace(index)
#     853
#     854     def __getitem__(self, indexer: Any):
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/indexes.py in _replace(self, index, dim, coord_dtype)
#     596             dim = self.dim
#     597         if coord_dtype is None:
# --> 598             coord_dtype = self.coord_dtype
#     599         return type(self)(index, dim, coord_dtype)
#     600
#
# AttributeError: 'PandasIndex' object has no attribute 'coord_dtype'

# %%
type(pkl_file)
# Out:
# xarray.core.dataset.Dataset

# %%
pkl_file['clon_bnds'].shape
# Out:
# (81920, 3)

# %%
data = pkl_file['clat_bnds']
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
titles = ['Dimension 1', 'Dimension 2', 'Dimension 3']

for i in range(3):
    axes[i].hist(data[:, i], bins=20, color='blue', alpha=0.7)
    axes[i].set_title(titles[i])
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
cl_area_22 = pkl_file['cl_area'][0,22,:].values

# %%
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent([-90.0, -60.0, -56.0, -10.0])  # Set the geographical extent

# Plotting the data
contour = ax.contourf(pkl_file['clon'], pkl_file['clat'], cl_area_22,
                      levels=[10*k for k in range(11)], cmap='Blues_r', transform=ccrs.PlateCarree())

# Adding features
ax.coastlines()  # Add coastlines
ax.gridlines(draw_labels=True)  # Add grid lines and labels

# Colorbar
cbar = plt.colorbar(contour, ax=ax, orientation='vertical', pad=0.05)
cbar.set_label('cl_area')
cbar.ax.tick_params(labelsize=20)  # Adjust the colorbar tick size

# Titles and labels
plt.title('REF (High-res)', fontsize=20)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-fa1006fd5c9d> in <cell line: 5>()
#       3
#       4 # Plotting the data
# ----> 5 contour = ax.contourf(pkl_file['clon'], pkl_file['clat'], cl_area_22,
#       6                       levels=[10*k for k in range(11)], cmap='Blues_r', transform=ccrs.PlateCarree())
#       7
#
# /usr/local/lib/python3.10/dist-packages/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     305
#     306         kwargs['transform'] = transform
# --> 307         return func(self, *args, **kwargs)
#     308     return wrapper
#     309
#
# /usr/local/lib/python3.10/dist-packages/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     349             # Use the new points as the input arguments
#     350             args = (x, y, z) + args[3:]
# --> 351         return func(self, *args, **kwargs)
#     352     return wrapper
#     353
#
# /usr/local/lib/python3.10/dist-packages/cartopy/mpl/geoaxes.py in contourf(self, *args, **kwargs)
#    1640             The default is False, to compute the contours in data-space.
#    1641         """
# -> 1642         result = super().contourf(*args, **kwargs)
#    1643
#    1644         # We need to compute the dataLim correctly for contours.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6465         """
#    6466         kwargs['filled'] = True
# -> 6467         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6468         self._request_autoscale_view()
#    6469         return contours
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, *args, **kwargs)
#     767                 mpl.rcParams['contour.negative_linestyle']
#     768
# --> 769         kwargs = self._process_args(*args, **kwargs)
#     770         self._process_levels()
#     771
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in _process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1409             self._corner_mask = corner_mask
#    1410
# -> 1411             x, y, z = self._contour_args(args, kwargs)
#    1412
#    1413             contour_generator = contourpy.contour_generator(
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1448         elif nargs <= 4:
#    1449             x, y, z_orig, *args = args
# -> 1450             x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1451         else:
#    1452             raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in _check_xyz(self, x, y, z, kwargs)
#    1473
#    1474         if z.ndim != 2:
# -> 1475             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1476         if z.shape[0] < 2 or z.shape[1] < 2:
#    1477             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#
# TypeError: Input z must be 2D, not 1D

# %%
# Ground Truth plot
plot = psy.plot.mapplot(pkl_file, name=['cl_area'], \
                        height=[22], time=[0], ax=(1, 1), sort=['height'], title = 'REF (High-res)', titlesize=20, cticksize=20, cmap='Blues_r', \
                        bounds=[10*k for k in range(11)], map_extent=[-90.0, -60.0, -56.0, -10.0], xgrid=True, ygrid=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-562c70780320> in <cell line: 2>()
#       1 # Ground Truth plot
# ----> 2 plot = psy.plot.mapplot(pkl_file, name=['cl_area'], \
#       3                         height=[22], time=[0], ax=(1, 1), sort=['height'], title = 'REF (High-res)', titlesize=20, cticksize=20, cmap='Blues_r', \
#       4                         bounds=[10*k for k in range(11)], map_extent=[-90.0, -60.0, -56.0, -10.0], xgrid=True, ygrid=True)
#
# /usr/local/lib/python3.10/dist-packages/psyplot/project.py in __call__(self, *args, **kwargs)
#    2209                     fmt.setdefault(key, val)
#    2210
# -> 2211         return self._project_plotter._add_data(
#    2212             self.plotter_cls,
#    2213             *args,
#
# /usr/local/lib/python3.10/dist-packages/psyplot/project.py in _add_data(self, *args, **kwargs)
#    1961         # method but is reimplemented by subclasses as the
#    1962         # :class:`DatasetPlotter` or the :class:`DataArrayPlotter`
# -> 1963         return self.project._add_data(*args, **kwargs)
#    1964
#    1965     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/psyplot/project.py in wrapper(self, *args, **kwargs)
#     184         if not self.is_main:
#     185             return getattr(self.main, func.__name__)(*args, **kwargs)
# --> 186         return func(self, *args, **kwargs)
#     187
#     188     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/psyplot/project.py in _add_data(self, plotter_cls, filename_or_obj, fmt, make_plot, draw, mf_mode, ax, engine, delete, share, clear, enable_post, concat_dim, load, *args, **kwargs)
#     851             enable_post = bool(fmt.get("post"))
#     852         # create the subproject
# --> 853         sub_project = self.from_dataset(filename_or_obj, **kwargs)
#     854         sub_project.main = self
#     855         sub_project.no_auto_update = not (
#
# /usr/local/lib/python3.10/dist-packages/psyplot/project.py in from_dataset(cls, *args, **kwargs)
#    1469         """
#    1470         main = kwargs.pop("main", None)
# -> 1471         ret = super(Project, cls).from_dataset(*args, **kwargs)
#    1472         if main is not None:
#    1473             ret.main = main
#
# /usr/local/lib/python3.10/dist-packages/psyplot/data.py in from_dataset(cls, base, method, default_slice, decoder, auto_update, prefer_list, squeeze, attrs, load, **kwargs)
#    4621         for key in set(chain(*six.itervalues(names))):
#    4622             utils.check_key(key, possible_keys, name="dimension")
# -> 4623         instance = cls(
#    4624             starmap(sel_method, six.iteritems(names)),
#    4625             attrs=base.attrs,
#
# /usr/local/lib/python3.10/dist-packages/psyplot/project.py in __init__(self, *args, **kwargs)
#     398         self._ds_counter = count()
#     399         with self.block_signals:
# --> 400             super(Project, self).__init__(*args, **kwargs)
#     401
#     402     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/psyplot/data.py in __init__(self, iterable, attrs, auto_update, new_name)
#    4327         self.auto_update = not bool(auto_update)
#    4328         # append the data in order to set the correct names
# -> 4329         self.extend(
#    4330             filter(
#    4331                 lambda arr: isinstance(
#
# /usr/local/lib/python3.10/dist-packages/psyplot/project.py in wrapper(self, *args, **kwargs)
#     197         if not self.is_main:
#     198             getattr(self.main, func.__name__)(*args, **kwargs)
# --> 199         return func(self, *args, **kwargs)
#     200
#     201     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/psyplot/project.py in extend(self, *args, **kwargs)
#     644     def extend(self, *args, **kwargs):
#     645         len0 = len(self)
# --> 646         ret = super(Project, self).extend(*args, **kwargs)
#     647         if self._main is None:
#     648             for arr in self:
#
# /usr/local/lib/python3.10/dist-packages/psyplot/data.py in extend(self, iterable, new_name)
#    5638         list.extend, append, rename"""
#    5639         # extend those arrays that aren't alredy in the list
# -> 5640         super(ArrayList, self).extend(
#    5641             t[0]
#    5642             for t in filter(
#
# /usr/local/lib/python3.10/dist-packages/psyplot/data.py in <genexpr>(.0)
#    5638         list.extend, append, rename"""
#    5639         # extend those arrays that aren't alredy in the list
# -> 5640         super(ArrayList, self).extend(
#    5641             t[0]
#    5642             for t in filter(
#
# /usr/local/lib/python3.10/dist-packages/psyplot/data.py in <genexpr>(.0)
#    5642             for t in filter(
#    5643                 lambda t: t[1] is not None,
# -> 5644                 (self.rename(arr, new_name) for arr in iterable),
#    5645             )
#    5646         )
#
# /usr/local/lib/python3.10/dist-packages/psyplot/data.py in sel_method(key, dims, name)
#    4521             def sel_method(key, dims, name=None):
#    4522                 if name is None:
# -> 4523                     return recursive_selection(key, dims, dims.pop("name"))
#    4524                 elif isinstance(
#    4525                     name, six.string_types
#
# /usr/local/lib/python3.10/dist-packages/psyplot/data.py in recursive_selection(key, dims, names)
#    4461                 return sel_method(key, dims, tuple(names))
#    4462             else:
# -> 4463                 return sel_method(key, dims, names[0])
#    4464
#    4465         def ds2arr(arr):
#
# /usr/local/lib/python3.10/dist-packages/psyplot/data.py in sel_method(key, dims, name)
#    4542                     }
#    4543                 )
# -> 4544                 add_missing_dimensions(arr)
#    4545                 ret = arr.isel(**dims)
#    4546                 if not isinstance(ret, xr.DataArray):
#
# /usr/local/lib/python3.10/dist-packages/psyplot/data.py in add_missing_dimensions(arr)
#    4499                     # old xarray version
#    4500                     size = base.dims[dim]
# -> 4501                 base[dim] = arr.coords[dim] = np.arange(size)
#    4502
#    4503         if squeeze:
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in __setitem__(self, key, value)
#    1601                     "object can be stored under a single key."
#    1602                 )
# -> 1603             self.update({key: value})
#    1604
#    1605         elif utils.iterable_of_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in update(self, other)
#    5621         Dataset.merge
#    5622         """
# -> 5623         merge_result = dataset_update_method(self, other)
#    5624         return self._replace(inplace=True, **merge_result._asdict())
#    5625
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/merge.py in dataset_update_method(dataset, other)
#    1053                     other[key] = value.drop_vars(coord_names)
#    1054
# -> 1055     return merge_core(
#    1056         [dataset, other],
#    1057         priority_arg=1,
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/merge.py in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value, skip_align_args)
#     690
#     691     coerced = coerce_pandas_values(objects)
# --> 692     aligned = deep_align(
#     693         coerced, join=join, copy=False, indexes=indexes, fill_value=fill_value
#     694     )
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/alignment.py in deep_align(objects, join, copy, indexes, exclude, raise_on_invalid, fill_value)
#     944             out.append(variables)
#     945
# --> 946     aligned = align(
#     947         *targets,
#     948         join=join,
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/alignment.py in align(join, copy, indexes, exclude, fill_value, *objects)
#     880         fill_value=fill_value,
#     881     )
# --> 882     aligner.align()
#     883     return aligner.results
#     884
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/alignment.py in align(self)
#     580             self.results = self.objects
#     581         else:
# --> 582             self.reindex_all()
#     583
#     584
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/alignment.py in reindex_all(self)
#     555
#     556     def reindex_all(self) -> None:
# --> 557         self.results = tuple(
#     558             self._reindex_one(obj, matching_indexes)
#     559             for obj, matching_indexes in zip(
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/alignment.py in <genexpr>(.0)
#     556     def reindex_all(self) -> None:
#     557         self.results = tuple(
# --> 558             self._reindex_one(obj, matching_indexes)
#     559             for obj, matching_indexes in zip(
#     560                 self.objects, self.objects_matching_indexes
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/alignment.py in _reindex_one(self, obj, matching_indexes)
#     544         dim_pos_indexers = self._get_dim_pos_indexers(matching_indexes)
#     545
# --> 546         return obj._reindex_callback(
#     547             self,
#     548             dim_pos_indexers,
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in _reindex_callback(self, aligner, dim_pos_indexers, variables, indexes, fill_value, exclude_dims, exclude_vars)
#    3441                 reindexed = self._overwrite_indexes(new_indexes, new_variables)
#    3442             else:
# -> 3443                 reindexed = self.copy(deep=aligner.copy)
#    3444         else:
#    3445             to_reindex = {
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in copy(self, deep, data)
#    1333         pandas.DataFrame.copy
#    1334         """
# -> 1335         return self._copy(deep=deep, data=data)
#    1336
#    1337     def _copy(
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in _copy(self, deep, data, memo)
#    1362                 )
#    1363
# -> 1364         indexes, index_vars = self.xindexes.copy_indexes(deep=deep)
#    1365
#    1366         variables = {}
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/indexes.py in copy_indexes(self, deep, memo)
#    1639                 convert_new_idx = False
#    1640
# -> 1641             new_idx = idx._copy(deep=deep, memo=memo)
#    1642             idx_vars = idx.create_variables(coords)
#    1643
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/indexes.py in _copy(self, deep, memo)
#     850             # index will be copied in constructor
#     851             index = self.index
# --> 852         return self._replace(index)
#     853
#     854     def __getitem__(self, indexer: Any):
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/indexes.py in _replace(self, index, dim, coord_dtype)
#     596             dim = self.dim
#     597         if coord_dtype is None:
# --> 598             coord_dtype = self.coord_dtype
#     599         return type(self)(index, dim, coord_dtype)
#     600
#
# AttributeError: 'PandasIndex' object has no attribute 'coord_dtype'

# %%
data = pkl_file

# %%
data['cl_area'].values.shape
# Out:
# (1, 27, 81920)

# %%
# Assuming 'data' is a dictionary and contains latitude and longitude grids
lat = data['clat']
lon = data['clon']
variable = data['cl_area'].values[0,22,:]  # Assuming indexing by time and height

# Create a figure and add a GeoAxes to the figure
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})

# Set the extent of the map
ax.set_extent([-90.0, -60.0, -56.0, -10.0], crs=ccrs.PlateCarree())

# Add gridlines
ax.gridlines(draw_labels=True, x_inline=False, y_inline=False)

# Plotting the data
contourf = ax.contourf(lon, lat, variable, levels=[10*k for k in range(11)], cmap='Blues_r', transform=ccrs.PlateCarree())

# Add colorbar
cbar = plt.colorbar(contourf, ax=ax, orientation='vertical')
cbar.ax.set_title('Scale')
cbar.ax.tick_params(labelsize=20)

# Set the title and its size
ax.set_title('REF (High-res)', fontsize=20)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-198d1f5f261c> in <cell line: 16>()
#      14
#      15 # Plotting the data
# ---> 16 contourf = ax.contourf(lon, lat, variable, levels=[10*k for k in range(11)], cmap='Blues_r', transform=ccrs.PlateCarree())
#      17
#      18 # Add colorbar
#
# /usr/local/lib/python3.10/dist-packages/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     305
#     306         kwargs['transform'] = transform
# --> 307         return func(self, *args, **kwargs)
#     308     return wrapper
#     309
#
# /usr/local/lib/python3.10/dist-packages/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     349             # Use the new points as the input arguments
#     350             args = (x, y, z) + args[3:]
# --> 351         return func(self, *args, **kwargs)
#     352     return wrapper
#     353
#
# /usr/local/lib/python3.10/dist-packages/cartopy/mpl/geoaxes.py in contourf(self, *args, **kwargs)
#    1640             The default is False, to compute the contours in data-space.
#    1641         """
# -> 1642         result = super().contourf(*args, **kwargs)
#    1643
#    1644         # We need to compute the dataLim correctly for contours.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6465         """
#    6466         kwargs['filled'] = True
# -> 6467         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6468         self._request_autoscale_view()
#    6469         return contours
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, *args, **kwargs)
#     767                 mpl.rcParams['contour.negative_linestyle']
#     768
# --> 769         kwargs = self._process_args(*args, **kwargs)
#     770         self._process_levels()
#     771
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in _process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1409             self._corner_mask = corner_mask
#    1410
# -> 1411             x, y, z = self._contour_args(args, kwargs)
#    1412
#    1413             contour_generator = contourpy.contour_generator(
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1448         elif nargs <= 4:
#    1449             x, y, z_orig, *args = args
# -> 1450             x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1451         else:
#    1452             raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/contour.py in _check_xyz(self, x, y, z, kwargs)
#    1473
#    1474         if z.ndim != 2:
# -> 1475             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1476         if z.shape[0] < 2 or z.shape[1] < 2:
#    1477             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#
# TypeError: Input z must be 2D, not 1D

# %%
pkl_file = contents['pickled_data/wgrid_20160811-15_timmean_sfs4nn-ref.pkl']

coordlist = ["clat_bnds", "clon_bnds"]
pkl_file = pkl_file.set_coords([coord for coord in pkl_file.data_vars if coord in coordlist])

# SFS4 - Ground Truth
plot = psy.plot.mapplot(pkl_file, name=['sfs4nn_pred'], \
                            height=[22], time=[0], ax=(1, 1), sort=['height'], title = 'SFS4-REF', titlesize=20, cticksize=20, cmap=cmap, \
                                bounds=[10*k for k in range(-10, 11)], map_extent=[-90.0, -60.0, -56.0, -10.0], xgrid=True, ygrid=True)

# %%
pkl_file = contents['pickled_data/wgrid_20160811-15_timmean_sfs5nn-ref.pkl']

coordlist = ["clat_bnds", "clon_bnds"]
pkl_file = pkl_file.set_coords([coord for coord in pkl_file.data_vars if coord in coordlist])

# SFS5 - Ground Truth
plot = psy.plot.mapplot(pkl_file, name=['sfs5nn_pred'], \
                            height=[22], time=[0], ax=(1, 1), sort=['height'], title = 'SFS5-REF', titlesize=20, cticksize=20, cmap=cmap, \
                                bounds=[10*k for k in range(-10, 11)], map_extent=[-90.0, -60.0, -56.0, -10.0], xgrid=True, ygrid=True)

# %%
pkl_file
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in __repr__(self)
#    1629
#    1630     def __repr__(self) -> str:
# -> 1631         return formatting.dataset_repr(self)
#    1632
#    1633     def _repr_html_(self):
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in dataset_repr(ds)
#     477
#     478     if ds.coords:
# --> 479         summary.append(coords_repr(ds.coords, col_width=col_width))
#     480
#     481     unindexed_dims_str = unindexed_dims_repr(ds.dims, ds.coords)
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in coords_repr(coords, col_width)
#     373     if col_width is None:
#     374         col_width = _calculate_col_width(_get_col_items(coords))
# --> 375     return _mapping_repr(
#     376         coords, title="Coordinates", summarizer=summarize_coord, col_width=col_width
#     377     )
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in _mapping_repr(mapping, title, summarizer, col_width)
#     354     summary = [f"{title}:"]
#     355     if mapping:
# --> 356         summary += [summarizer(k, v, col_width) for k, v in mapping.items()]
#     357     else:
#     358         summary += [EMPTY_REPR]
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in <listcomp>(.0)
#     354     summary = [f"{title}:"]
#     355     if mapping:
# --> 356         summary += [summarizer(k, v, col_width) for k, v in mapping.items()]
#     357     else:
#     358         summary += [EMPTY_REPR]
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in summarize_coord(name, var, col_width)
#     308                 ]
#     309             )
# --> 310     return summarize_variable(name, var.variable, col_width, marker)
#     311
#     312
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in summarize_variable(name, var, col_width, marker, max_width)
#     271
#     272     values_width = max_width - len(front_str)
# --> 273     values_str = inline_variable_array_repr(var, values_width)
#     274
#     275     return front_str + values_str
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in inline_variable_array_repr(var, max_width)
#     247     """Build a one-line summary of a variable's data."""
#     248     if var._in_memory:
# --> 249         return format_array_flat(var, max_width)
#     250     elif isinstance(var._data, dask_array_type):
#     251         return inline_dask_repr(var.data)
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in format_array_flat(array, max_width)
#     173         max(array.size, 1), max(int(np.ceil(max_width / 2.0)), 2)
#     174     )
# --> 175     relevant_front_items = format_items(
#     176         first_n_items(array, (max_possibly_relevant + 1) // 2)
#     177     )
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in format_items(x)
#     160             timedelta_format = "date"
#     161
# --> 162     formatted = [format_item(xi, timedelta_format) for xi in x]
#     163     return formatted
#     164
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in <listcomp>(.0)
#     160             timedelta_format = "date"
#     161
# --> 162     formatted = [format_item(xi, timedelta_format) for xi in x]
#     163     return formatted
#     164
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in format_item(x, timedelta_format, quote_strings)
#     140     elif isinstance(x, (str, bytes)):
#     141         return repr(x) if quote_strings else x
# --> 142     elif isinstance(x, (float, np.float)):
#     143         return f"{x:.4}"
#     144     else:
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     317
#     318         if attr in __former_attrs__:
# --> 319             raise AttributeError(__former_attrs__[attr])
#     320
#     321         if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in _repr_html_(self)
#    1633     def _repr_html_(self):
#    1634         if OPTIONS["display_style"] == "text":
# -> 1635             return f"<pre>{escape(repr(self))}</pre>"
#    1636         return formatting_html.dataset_repr(self)
#    1637
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/dataset.py in __repr__(self)
#    1629
#    1630     def __repr__(self) -> str:
# -> 1631         return formatting.dataset_repr(self)
#    1632
#    1633     def _repr_html_(self):
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in dataset_repr(ds)
#     477
#     478     if ds.coords:
# --> 479         summary.append(coords_repr(ds.coords, col_width=col_width))
#     480
#     481     unindexed_dims_str = unindexed_dims_repr(ds.dims, ds.coords)
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in coords_repr(coords, col_width)
#     373     if col_width is None:
#     374         col_width = _calculate_col_width(_get_col_items(coords))
# --> 375     return _mapping_repr(
#     376         coords, title="Coordinates", summarizer=summarize_coord, col_width=col_width
#     377     )
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in _mapping_repr(mapping, title, summarizer, col_width)
#     354     summary = [f"{title}:"]
#     355     if mapping:
# --> 356         summary += [summarizer(k, v, col_width) for k, v in mapping.items()]
#     357     else:
#     358         summary += [EMPTY_REPR]
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in <listcomp>(.0)
#     354     summary = [f"{title}:"]
#     355     if mapping:
# --> 356         summary += [summarizer(k, v, col_width) for k, v in mapping.items()]
#     357     else:
#     358         summary += [EMPTY_REPR]
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in summarize_coord(name, var, col_width)
#     308                 ]
#     309             )
# --> 310     return summarize_variable(name, var.variable, col_width, marker)
#     311
#     312
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in summarize_variable(name, var, col_width, marker, max_width)
#     271
#     272     values_width = max_width - len(front_str)
# --> 273     values_str = inline_variable_array_repr(var, values_width)
#     274
#     275     return front_str + values_str
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in inline_variable_array_repr(var, max_width)
#     247     """Build a one-line summary of a variable's data."""
#     248     if var._in_memory:
# --> 249         return format_array_flat(var, max_width)
#     250     elif isinstance(var._data, dask_array_type):
#     251         return inline_dask_repr(var.data)
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in format_array_flat(array, max_width)
#     173         max(array.size, 1), max(int(np.ceil(max_width / 2.0)), 2)
#     174     )
# --> 175     relevant_front_items = format_items(
#     176         first_n_items(array, (max_possibly_relevant + 1) // 2)
#     177     )
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in format_items(x)
#     160             timedelta_format = "date"
#     161
# --> 162     formatted = [format_item(xi, timedelta_format) for xi in x]
#     163     return formatted
#     164
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in <listcomp>(.0)
#     160             timedelta_format = "date"
#     161
# --> 162     formatted = [format_item(xi, timedelta_format) for xi in x]
#     163     return formatted
#     164
#
# /usr/local/lib/python3.10/dist-packages/xarray/core/formatting.py in format_item(x, timedelta_format, quote_strings)
#     140     elif isinstance(x, (str, bytes)):
#     141         return repr(x) if quote_strings else x
# --> 142     elif isinstance(x, (float, np.float)):
#     143         return f"{x:.4}"
#     144     else:
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     317
#     318         if attr in __former_attrs__:
# --> 319             raise AttributeError(__former_attrs__[attr])
#     320
#     321         if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ### Functional Representation

# %%
def plot_pickle_file(file_name, bins, color):
    with open('pickled_data/' + file_name, 'rb') as file:
        pkl_file = pickle.load(file)
        plt.plot((bins[1:] + bins[:-1])/2, pkl_file, color=color)

# %%
N_bins=10
bins = np.linspace(0, 0.7, N_bins)

plot_pickle_file('nn_preds_cold_cond_%d_bins.pkl'%N_bins, bins, 'cyan')
plot_pickle_file('pysr_preds_cold_cond_%d_bins.pkl'%N_bins, bins, 'brown')
plot_pickle_file('sundq_preds_cold_cond_%d_bins.pkl'%N_bins, bins, 'blue')
plot_pickle_file('cold_output_cond_%d_bins.pkl'%N_bins, bins, 'black')

plt.legend(['NN', 'PySR equation', 'Sundqvist scheme', 'Reference'])

plt.title('Cold Decile (%d RH bins)'%N_bins)
plt.xlabel('Relative Humidity')
plt.ylabel('Cloud (Area) Fraction')

# %%
N_bins=10
bins = np.linspace(0, 1.2, N_bins)

plot_pickle_file('nn_preds_hot_cond_%d_bins.pkl'%N_bins, bins, 'cyan')
plot_pickle_file('pysr_preds_hot_cond_%d_bins.pkl'%N_bins, bins, 'brown')
plot_pickle_file('sundq_preds_hot_cond_%d_bins.pkl'%N_bins, bins, 'blue')
plot_pickle_file('hot_output_cond_%d_bins.pkl'%N_bins, bins, 'black')

plt.legend(['NN', 'PySR equation', 'Sundqvist scheme', 'Reference'])

plt.title('Hot Decile (%d RH bins)'%N_bins)
plt.xlabel('Relative Humidity')
plt.ylabel('Cloud (Area) Fraction')

# %% [markdown]
# # Schematic to showcase the added value of nonlinearity

# %%
# Generate 50 random numbers between 0 and 1
X = 3*np.random.rand(100)

# Generate noise that linearly increases with X
noise = np.random.normal(scale=X)

# Generate 50 random Y values following an exponential of X with noise
Y = np.exp(X) + noise

# Generate 10^4 points for true X and true Y
true_X = 3*np.random.rand(10000)
true_noise = np.random.normal(scale=true_X)
true_Y = np.exp(true_X) + true_noise

# Display X and Y
print("X:", X)
print("Y:", Y)
# Out:
# X: [1.42463851 0.97115209 1.7535896  1.51193199 2.61488157 1.14693008
#  0.0318853  1.37564872 2.62091071 1.3249872  2.96431621 0.4776456
#  0.24696168 1.69050758 1.93376005 2.18685087 2.5381222  2.94141354
#  1.92151012 1.20458181 1.26197255 1.84897037 0.48444802 1.67740154
#  0.40210556 1.92013437 1.18501342 2.02539698 1.474539   0.97662048
#  2.55810761 2.32271553 1.81743858 2.54125985 2.02899688 1.65034939
#  2.63995584 2.56625379 2.76878363 0.60633716 0.91335014 1.46650423
#  0.56799756 0.87016104 1.35313814 1.62451158 1.73989285 0.37318543
#  0.91683388 0.934398   0.55399524 0.77622482 0.48563442 2.88487382
#  1.0041262  1.27047579 0.8036461  1.1335986  0.39571859 2.7261092
#  1.34771095 2.18986648 0.44998806 1.50002007 2.67417896 1.73691854
#  1.54163155 2.17159893 1.25325481 2.4987103  1.4622258  2.55467506
#  0.58352719 2.47864925 2.5461535  0.59476126 1.27086067 1.7341946
#  2.55650416 0.7232326  0.03160307 1.03650949 1.7127782  1.11034893
#  1.82377215 1.52950863 0.58330604 2.51590034 1.71618391 0.99813759
#  2.48046296 2.25207018 2.96089452 1.35658012 0.48224381 1.33744776
#  2.6713498  1.51362921 0.75613749 2.42565024]
# Y: [ 4.21348624  2.46889907  6.98620285  2.42807395  8.51123053  1.00951563
#   1.04010759  2.84930661 14.57489578  3.03548548 20.30253845  1.85926595
#   1.19262431  8.5540005   8.2409794   6.69216729 12.35144548 18.51620245
#   6.65846232  4.63763869  2.93003462  2.35344988  1.0253715   4.29906683
#   1.80296267 10.85896652  3.35669342  6.40062506  1.04984922  1.80230403
#  15.36426654  8.68062393  4.07530513  9.68987275  8.76147582  2.36088434
#  15.27382339 13.32463798 10.35022383  0.77113702  3.60555772  5.16097096
#   1.24777948  2.03711115  4.2149625   2.60143491  4.74033743  1.59580063
#   1.34550977  2.90518134  1.86610327  2.0273809   1.39340724 21.17403533
#   3.58335106  3.25608008  1.86043096  3.0088777   1.51100949 14.63012108
#   4.13402272  8.0091392   1.84332672  2.50401053  5.90261146  4.89690754
#   2.50237693  8.32211559  2.57389252 10.75761714  3.87825526 16.29341553
#   1.51093841 15.89280546 14.46337034  1.69674221  4.67238363  7.19112807
#  13.48664828  0.15074759  1.06510405  2.4571115   5.90073995  2.85362258
#   8.10914355  4.49212809  2.87305974 13.5507303   4.00763684  3.22670804
#  10.50721315 11.68860321 21.91092868  5.26593094  2.1170272   4.01734513
#  17.38529525  4.91627718  2.26178155 13.62011596]

# %%
# Scatter plot
fig = plt.figure(figsize=(11, 4))
ax = fig.add_subplot(111)
plt.scatter(X, Y, c='skyblue', edgecolors='navy', linewidth=1.5, label='Data')

# Linear regression
slope, intercept, _, _, _ = linregress(X, Y)
plt.plot(X, slope*X + intercept, color='red', label='Linear Baseline')

# # Plot the true Y as a function of true X
bin_means, bin_edges, _ = binned_statistic(true_X, true_Y, statistic='mean', bins=10)
# Adjust bin_edges to have the same length as bin_means for plotting
bin_edg = bin_edges[:-1] + np.diff(bin_edges) / 2
plt.plot(bin_edg, bin_means, linestyle = '--',
         color='green')

bin_conf_int = [np.percentile(true_Y[(true_X >= bin_edges[i]) & (true_X < bin_edges[i+1])], [1, 99]) for i in range(len(bin_means))]
plt.fill_between(bin_edg, [ci[0] for ci in bin_conf_int], [ci[1] for ci in bin_conf_int],
                 color='lightgreen', alpha=0.2, label='Added value: Uncertainty Quantification')

# Exponential regression
coefficients = np.polyfit(X, np.log(Y), 1)
X_exp = np.linspace(0,3,1000)
Y_exp = np.exp(coefficients[1]) * np.exp(coefficients[0]*X_exp)
plt.plot(X_exp, Y_exp, color='orange', label='Added value: Nonlinearity')

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)

# Set labels with latex font
plt.xlabel(r'Feature $X$', fontsize=20, labelpad=-25)  # Adjust labelpad value as needed
plt.ylabel(r'Target $Y$',fontsize=20)

# Set the number of ticks
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=5)

# Remove x and y tick labels
# x
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
# y
labels = [item.get_text() for item in ax.get_yticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)

leg0 = plt.legend(fontsize=18)
plt.draw()

# Find the legend text you want to change. Assuming 'Added value: Uncertainty Quantification' is unique,
# this will change its color.
for text in leg0.get_texts():
    if 'Added value' in text.get_text():
      text.set_color((0.33, 0.42, 0.18))  # Dark olive green RGB
    elif 'Baseline' in text.get_text():
      text.set_color((1.0, 0.2, 0.0)) # Orange RGB

# Show plot
plt.show()
# Out:
# <ipython-input-14-7f553a2d7d0e>:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(empty_string_labels)
# <ipython-input-14-7f553a2d7d0e>:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(empty_string_labels)

# %% [markdown]
# # Schematic to showcast the added value of temporal connectivity

# %%
# Define the time series duration and sampling rate
t = np.linspace(0, 1, 100)  # time vector

# Define the sinusoidal waves
fast_wave = 0.5*np.sin(2 * np.pi * 10 * t)  # fast wave with a frequency of 10 Hz
fq = 2+0.5*fast_wave
slow_wave = np.cos(2 * np.pi * fq * t)  # slow wave with a frequency that depends on the fast wave

# Generate normal (Gaussian) noise
noise = 1.5*np.random.normal(0, 0.2, t.shape)

# Superpose the waves and add noise
time_series = fast_wave + slow_wave + noise

# Baseline model based on the slow wave only and a fixed frequency of 2Hz
baseline_model = np.cos(2 * np.pi * 2 * t)

# Model using more points in the past
smarter_model = slow_wave + fast_wave

# %%
# Find the 3 closest points to the baseline model for t < 0.5
distances_baseline = np.abs(time_series[:50] - baseline_model[:50])
indices_baseline_close = np.argsort(distances_baseline)[:3]

# Find the 25 closest points to the smarter model for t < 0.5
distances_smarter = np.abs(time_series[:50] - smarter_model[:50])
indices_smarter_close = np.argsort(distances_smarter)[:25]

# %%
# Scatter plot
fig = plt.figure(figsize=(11, 4))
ax = fig.add_subplot(111)

# Apply different background colors for time before and after prediction (at t=0.5)
ax.axvspan(0, 0.5, color='lightgrey', alpha=0.5)
ax.axvspan(0.5, 1, color='whitesmoke', alpha=0.5)

plt.scatter(t, time_series, c='skyblue', edgecolors='navy', linewidth=1.5, label='Data')
# plt.plot(t[:50], baseline_model[:50], 'r-', linewidth=2, linestyle=':')
# plt.plot(t[:50], smarter_model[:50], 'g-', linewidth=2, linestyle=':')
plt.plot(t[50:], baseline_model[50:], 'r-', linewidth=2, label='Baseline')
plt.plot(t[50:], smarter_model[50:], 'g-', linewidth=2, label='Added value: Refined temporal information')
plt.ylim((-2.1,4.1))

# Circle the 5 closest points to the baseline model with red for t<0.5
plt.scatter(t[indices_baseline_close], time_series[indices_baseline_close], s=100, facecolors='none', edgecolors='r')

# Circle the 15 closest points to the smarter model with green for t<0.5
plt.scatter(t[indices_smarter_close], time_series[indices_smarter_close], s=100, facecolors='none', edgecolors='g')

Y_text = 3.6
# Titles with arrows
ax.text(0.25, Y_text, 'Training', horizontalalignment='center', fontsize=20)
ax.text(0.75, Y_text, 'Prediction', horizontalalignment='center', fontsize=20)

Y_arrow = 3.7
# Adjusted Arrows for "Training"
ax.annotate('', xy=(0, Y_arrow), xytext=(0.175, Y_arrow),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8))
ax.annotate('', xy=(0.5, Y_arrow), xytext=(0.325, Y_arrow),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8))

# Adjusted Arrows for "Prediction"
ax.annotate('', xy=(0.5, Y_arrow), xytext=(0.675, Y_arrow),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8))
ax.annotate('', xy=(1, Y_arrow), xytext=(0.825, Y_arrow),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8))

plt.xlabel(r'Time',fontsize=20,labelpad=-30)

ax.yaxis.set_label_position("right")
ax.yaxis.tick_right()
plt.ylabel(r'Target $Y$',fontsize=20)

leg0 = plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.92), fontsize=17,ncol=3)
plt.grid(True)

# x
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
# y
labels = [item.get_text() for item in ax.get_yticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)

plt.draw()

# Find the legend text you want to change. Assuming 'Added value: Uncertainty Quantification' is unique,
# this will change its color.
for text in leg0.get_texts():
    if 'Added value' in text.get_text():
      text.set_color((0.33, 0.42, 0.18))  # Dark olive green RGB
    elif 'Baseline' in text.get_text():
      text.set_color((1.0, 0.2, 0.0)) # Orange RGB

plt.show()
# Out:
# <ipython-input-22-5c80c9178710>:52: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(empty_string_labels)
# <ipython-input-22-5c80c9178710>:56: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(empty_string_labels)

# %% [markdown]
# # Deterministic, AI-based, Medium-Range Weather Forecasting

# %%
# Create a dictionary storing performance and number of parameters for each model
MWF = {}

# %%
# Start with number of parameters
MWF['WeynCNN2019'] = 200e3
MWF['WeynCNN2020'] = 700e3
MWF['Rasp2020'] = 6.3e6
MWF['Keisler'] = 6.7e6
MWF['Pathak'] = 75e6
MWF['GraphCast'] = 37e6
MWF['Pangu'] = 256e6
